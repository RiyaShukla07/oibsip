# %% [markdown]
# <a href="https://colab.research.google.com/github/RiyaShukla07/oibsip/blob/main/unemployment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **RIYA SHUKLA**
#
# Data Science Analysis with python

# %% [markdown]
# Task 2 - Unemployment Analysis with python

# %% [markdown]
# PROBLEM STATEMENT
#
# Unemployment is measured by the unemployment rate which is the number of people
# who are unemployed as a percentage of the total labour force. We have seen a sharp
# increase in the unemployment rate during Covid-19, so analyzing the unemployment rate
# can be a good data science project.

# %% [markdown]
# 1.Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# Loading the dataset

# %%
data = pd.read_csv('/Unemployment in India.csv')
data_11_2020 = pd.read_csv('/Unemployment_Rate_upto_11_2020.csv')

# %%
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data_11_2020.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
data_11_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
data = data.dropna()
data.shape
# Out:
# (740, 7)

# %%
data_11_2020.shape
# Out:
# (267, 9)

# %%
data.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
data_11_2020.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
data.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data_11_2020.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data_11_2020.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data.shape
# Out:
# (740, 7)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data_11_2020.duplicated().sum()
# Out:
# 0

# %%
# rename all columns name
data.columns = ['State','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Area']

# %%
data_11_2020.columns = ['State','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Region','Longitude','Latitude']

# %%
data.columns
# Out:
# Index(['State', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Area'],
#       dtype='object')

# %%
data_11_2020.columns
# Out:
# Index(['State', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Region',
#        'Longitude', 'Latitude'],
#       dtype='object')

# %%
data.head(2)
# Out:
#             State         Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1  Andhra Pradesh   30-06-2019   Monthly                         3.05
#
#    Estimated Employed  Estimated Labour Participation Rate   Area
# 0          11999139.0                                43.24  Rural
# 1          11755881.0                                42.05  Rural

# %%
data_11_2020.head(2)
# Out:
#             State         Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh   31-01-2020         M                         5.48
# 1  Andhra Pradesh   29-02-2020         M                         5.83
#
#    Estimated Employed  Estimated Labour Participation Rate Region  Longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
#
#    Latitude
# 0     79.74
# 1     79.74

# %%
# State with highest unemployment
data['State'].value_counts().idxmax()
# idxmax() returns the index (the value) with the highest count.
# Out:
# 'Andhra Pradesh'

# %%
data['State'].value_counts()
# Out:
# State
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
data_11_2020['State'].value_counts().idxmax()
# Out:
# 'Andhra Pradesh'

# %%
# State with lowest unemployment
data['State'].value_counts().idxmin()
# Out:
# 'Chandigarh'

# %%
data_11_2020['State'].value_counts().idxmin()
# Out:
# 'Sikkim'

# %%
# Month of Unemployment
# These code converts the 'Date' column to a datetime type,extracts the month as an integer, and adds a new column
# With the corresponding three-letter month abbreviation.

import datetime as dt
import calendar

data['Date'] = pd.to_datetime(data['Date'],  dayfirst=True)
data['month_int'] = data['Date'].dt.month
data['month'] = (data['month_int'].astype(int)).apply(lambda x: calendar.month_abbr[x])

# %%
data_11_2020['Date'] = pd.to_datetime(data_11_2020['Date'],  dayfirst=True)
data_11_2020['month_int'] = data_11_2020['Date'].dt.month
data_11_2020['month'] = data_11_2020['month_int'].apply(lambda x: calendar.month_abbr[x])

# %%
# months with highest unemployment

data['month'].value_counts().idxmax()
# Out:
# 'May'

# %%
data_11_2020['month'].value_counts().idxmax
# Out:
# <bound method Series.idxmax of month
# Mar    27
# May    27
# Jun    27
# Jul    27
# Aug    27
# Sep    27
# Oct    27
# Jan    26
# Feb    26
# Apr    26
# Name: count, dtype: int64>

# %%
# month with lowest unemployment
data['month'].value_counts().idxmin()
# Out:
# 'Apr'

# %%
data_11_2020['month'].value_counts().idxmin()
# Out:
# 'Jan'

# %%
data.head(3)
# Out:
#             State       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
#
#    Estimated Employed  Estimated Labour Participation Rate   Area  month_int  \
# 0          11999139.0                                43.24  Rural          5
# 1          11755881.0                                42.05  Rural          6
# 2          12086707.0                                43.50  Rural          7
#
#   month
# 0   May
# 1   Jun
# 2   Jul

# %%
data_11_2020.head(3)
# Out:
#             State       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2020-01-31         M                         5.48
# 1  Andhra Pradesh 2020-02-29         M                         5.83
# 2  Andhra Pradesh 2020-03-31         M                         5.79
#
#    Estimated Employed  Estimated Labour Participation Rate Region  Longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
#
#    Latitude  month_int month
# 0     79.74          1   Jan
# 1     79.74          2   Feb
# 2     79.74          3   Mar

# %%
data.drop(columns=['Frequency','month_int'])
# Out:
#               State       Date  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2019-05-31                         3.65
# 1    Andhra Pradesh 2019-06-30                         3.05
# 2    Andhra Pradesh 2019-07-31                         3.75
# 3    Andhra Pradesh 2019-08-31                         3.32
# 4    Andhra Pradesh 2019-09-30                         5.17
# ..              ...        ...                          ...
# 749     West Bengal 2020-02-29                         7.55
# 750     West Bengal 2020-03-31                         6.67
# 751     West Bengal 2020-04-30                        15.63
# 752     West Bengal 2020-05-31                        15.22
# 753     West Bengal 2020-06-30                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate   Area month
# 0            11999139.0                                43.24  Rural   May
# 1            11755881.0                                42.05  Rural   Jun
# ...

# %%
data_11_2020.drop(columns=['Frequency','month_int'])
# Out:
#               State       Date  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2020-01-31                         5.48
# 1    Andhra Pradesh 2020-02-29                         5.83
# 2    Andhra Pradesh 2020-03-31                         5.79
# 3    Andhra Pradesh 2020-04-30                        20.51
# 4    Andhra Pradesh 2020-05-31                        17.43
# ..              ...        ...                          ...
# 262     West Bengal 2020-06-30                         7.29
# 263     West Bengal 2020-07-31                         6.83
# 264     West Bengal 2020-08-31                        14.87
# 265     West Bengal 2020-09-30                         9.35
# 266     West Bengal 2020-10-31                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region  \
# 0              16635535                                41.02  South
# 1              16545652                                40.90  South
# ...

# %%
# top 10 states with highest unemployment

data1 = data[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate', ascending=False)

# %%
data1_11_2020 = data_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate', ascending=False)

# %%
data1.head(10)
# Out:
#                   Estimated Unemployment Rate
# State
# Tripura                                793.81
# Haryana                                735.93
# Jharkhand                              576.38
# Bihar                                  529.71
# Himachal Pradesh                       519.13
# Delhi                                  461.87
# Rajasthan                              393.63
# Uttar Pradesh                          351.44
# Jammu & Kashmir                        339.96
# Punjab                                 336.87

# %%
data1_11_2020.head(10)
# Out:
#                   Estimated Unemployment Rate
# State
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68
# Jammu & Kashmir                        148.30
# Tamil Nadu                             121.87

# %%
# visualisation

fig = plt.figure()
ax0 = fig.add_subplot(1,2,1)
data1[:10].plot(kind='bar', color='brown', figsize=(30,5),ax=ax0)
ax0.set_title('Top 10 States with highest')
ax0.set_xlabel('State')
ax0.set_ylabel('Number of people unemployment %')
# Out:
# Text(0, 0.5, 'Number of people unemployment %')

# %%
fig = plt.figure()
ax0 = fig.add_subplot(1,2,1)
data1_11_2020[:10].plot(kind='bar', color='blue', figsize=(30,5),ax=ax0)
ax0.set_title('Top 10 States with highest')
ax0.set_xlabel('State')
ax0.set_ylabel('Number of people unemployment %')
# Out:
# Text(0, 0.5, 'Number of people unemployment %')

# %%
# month with highest unemployment

data2 = data[['month','Estimated Unemployment Rate']].groupby('month').sum().sort_values(by='Estimated Unemployment Rate', ascending=False)
data2.head(10)
# Out:
#        Estimated Unemployment Rate
# month
# May                        1747.85
# Apr                        1205.72
# Jun                        1097.56
# Mar                         556.43
# Oct                         544.55
# Nov                         542.76
# Feb                         528.13
# Jan                         527.39
# Aug                         510.81
# Dec                         503.36

# %%
data2_11_2020 = data_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values(by ='Estimated Unemployment Rate', ascending=False)
data2_11_2020.head(10)
# Out:
#                   Estimated Unemployment Rate
# State
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68
# Jammu & Kashmir                        148.30
# Tamil Nadu                             121.87

# %%
fig = plt.figure()
ax0 = fig.add_subplot(1,2,1)
data2[:12].plot(kind='bar', color='deeppink', figsize=(30,5),ax=ax0)
ax0.set_title('Top 10 States with highest')
ax0.set_xlabel('State')
ax0.set_ylabel('Number of people unemployment %')
# Out:
# Text(0, 0.5, 'Number of people unemployment %')

# %%
fig = plt.figure()
ax0 = fig.add_subplot(1,2,1)
data2_11_2020[:12].plot(kind='bar', color='green', figsize=(30,5),ax=ax0)
ax0.set_title('Month with highest unemployment')
ax0.set_xlabel('Region')
ax0.set_ylabel('Number of people unemployment (in %)')
# Out:
# Text(0, 0.5, 'Number of people unemployment (in %)')

# %%
# visualize labor participation rate and unemployment rate in each month

data_EEE = data.groupby(['month'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean()
data_EEE = pd.DataFrame(data_EEE).reset_index()
month = data_EEE.month
unemployment_rate = data_EEE['Estimated Unemployment Rate']
labor_participation_rate = data_EEE['Estimated Labour Participation Rate']

fig = go.Figure()

fig.add_trace(go.Bar(x = month, y = unemployment_rate, name = 'unemployment_Rate'))
fig.add_trace(go.Bar(x = month, y = labor_participation_rate, name = 'Labor Participation Rate'))

fig.update_layout(title='Unemployment Rate and Labor Participation Rate', xaxis={'categoryorder':'array', 'categoryarray':['Jan'],})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_EEE_11_2020 = data_11_2020.groupby(['month'])[['Estimated Unemployment Rate','Estimated Employed','Estimated Labour Participation Rate']].mean()
data_EEE_11_2020 = pd.DataFrame(data_EEE_11_2020).reset_index()
month = data_EEE_11_2020.month
unemployment_rate = data_EEE_11_2020['Estimated Unemployment Rate']
labor_participation_rate = data_EEE_11_2020['Estimated Labour Participation Rate']

fig = go.Figure()

fig.add_trace(go.Bar(x = month, y = unemployment_rate, name = 'unemployment_Rate'))
fig.add_trace(go.Bar(x = month, y = labor_participation_rate, name = 'Labor Participation Rate'))

fig.update_layout(title='Unemployment Rate and Labor Participation Rate', xaxis={'categoryorder':'array', 'categoryarray':['Jan'],})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# state wise Estimated Employed(Estimates Employed --> It represents the count of people who have jobs or are engaged in some form of emplyment)
data3 = data[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed', ascending=False)
data3
# Out:
#                   Estimated Employed
# State
# Uttar Pradesh            786655301.0
# Maharashtra              559725484.0
# West Bengal              481559064.0
# Bihar                    346253296.0
# Tamil Nadu               343547309.0
# Gujarat                  319256358.0
# Madhya Pradesh           311233561.0
# Karnataka                298679340.0
# Rajasthan                281149813.0
# Andhra Pradesh           228314609.0
# Telangana                222310557.0
# Odisha                   183280915.0
# Assam                    139224076.0
# Punjab                   127102136.0
# Jharkhand                125138732.0
# Kerala                   123925186.0
# Chhattisgarh             120497960.0
# Haryana                   99598029.0
# Delhi                     73570360.0
# Jammu & Kashmir           37798565.0
# Uttarakhand               37536159.0
# Himachal Pradesh          29675064.0
# Tripura                   20076074.0
# Meghalaya                 18622894.0
# ...

# %%
# state wise Estimated Employed visualization

data3 = data[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed', ascending=False)
data3.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)



#Employed
data3[:10].plot(kind='bar',color='green', figsize=(15,6), ax=ax1)
ax1.set_title('Estimated Employed people in each state')
ax1.set_title('State')
ax1.set_ylabel('Number of Estimated Employed')
# Out:
# Text(0, 0.5, 'Number of Estimated Employed')

# %%
# Estimated Unemploymeent Rate state wise(Estimated Unemployment Rate (%))

data3_a = data[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate', ascending=False)
data3_a
# Out:
#                   Estimated Unemployment Rate
# State
# Tripura                                793.81
# Haryana                                735.93
# Jharkhand                              576.38
# Bihar                                  529.71
# Himachal Pradesh                       519.13
# Delhi                                  461.87
# Rajasthan                              393.63
# Uttar Pradesh                          351.44
# Jammu & Kashmir                        339.96
# Punjab                                 336.87
# Kerala                                 283.47
# Puducherry                             265.59
# Tamil Nadu                             259.96
# Chhattisgarh                           258.73
# West Bengal                            227.49
# Goa                                    222.58
# Telangana                              216.66
# Maharashtra                            211.61
# Andhra Pradesh                         209.36
# ...

# %%
#Estimated Unemployment Rate state wise visualization

data3_a = data[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate', ascending=False)
data3_a.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

data3_a[:10].plot(kind='bar',color='violet', figsize=(15,6), ax=ax1)
ax1.set_title('Estimated Unemployment rate in each state')
ax1.set_title('State')
ax1.set_ylabel('Estimated Unemployment Rate (in %)')
# Out:
# Text(0, 0.5, 'Estimated Unemployment Rate (in %)')

# %%
# Estimated Unemploymeent Rate state wise(Estimated Unemployment Rate (%))

data3_a_11_2020 = data_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate', ascending=False)
data3_a_11_2020
# Out:
#                   Estimated Unemployment Rate
# State
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68
# Jammu & Kashmir                        148.30
# Tamil Nadu                             121.87
# Goa                                    121.67
# Punjab                                 119.81
# Uttarakhand                            111.56
# West Bengal                            101.92
# Uttar Pradesh                           97.37
# Kerala                                  94.34
# Andhra Pradesh                          86.64
# Maharashtra                             79.79
# Sikkim                                  78.34
# ...

# %%
#Estimated Unemployment Rate state wise visualization

data3_a_11_2020 = data_11_2020[['State','Estimated Unemployment Rate']].groupby('State').sum().sort_values('Estimated Unemployment Rate', ascending=False)
data3_a_11_2020.head(10)
fig=plt.figure()
ax0=fig.add_subplot(1,2,2)

data3_a_11_2020[:10].plot(kind='bar',color='yellow', figsize=(15,6), ax=ax0)
ax0.set_title('Estimated Unemployment Rate in each state')
ax0.set_title('State')
ax0.set_ylabel('Estimated Unemployment Rate (in %)')
# Out:
# Text(0, 0.5, 'Estimated Unemployment Rate (in %)')

# %%
# state wise Estimated Employed


data3_11_2020 = data_11_2020[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed', ascending=False)
data3_a_11_2020
# Out:
#                   Estimated Unemployment Rate
# State
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68
# Jammu & Kashmir                        148.30
# Tamil Nadu                             121.87
# Goa                                    121.67
# Punjab                                 119.81
# Uttarakhand                            111.56
# West Bengal                            101.92
# Uttar Pradesh                           97.37
# Kerala                                  94.34
# Andhra Pradesh                          86.64
# Maharashtra                             79.79
# Sikkim                                  78.34
# ...

# %%
# state wise Estimated Employed visualization

data3_11_2020 = data_11_2020[['State','Estimated Employed']].groupby('State').sum().sort_values('Estimated Employed', ascending=False)
data3_11_2020.head(10)
fig=plt.figure()
ax0=fig.add_subplot(1,2,2)

#estimated employed
data3_11_2020[:10].plot(kind='bar',color='orange', figsize=(15,6), ax=ax0)
ax0.set_title('Estimated Employed people in each state')
ax0.set_title('State')
ax0.set_ylabel('Number of Estimated Unemployed People')
# Out:
# Text(0, 0.5, 'Number of Estimated Unemployed People')

# %%
data4 = data[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed', ascending=False)
data4
# Out:
#        Estimated Employed
# month
# Jun           766717078.0
# May           699995530.0
# Jan           406899254.0
# Feb           403011803.0
# Sep           402452126.0
# Oct           401411032.0
# Nov           400051335.0
# Jul           399838967.0
# Aug           399610205.0
# Dec           391001555.0
# Mar           390862219.0
# Apr           269449315.0

# %%
#month wise Estimated Employed visualization

data4 = data[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed', ascending=False)
data4.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

# employed
data4[:10].plot(kind='bar',color='red', figsize=(15,6), ax=ax0)
ax1.set_title('Estimated Employed people in each Month')
ax1.set_title('Month')
ax1.set_ylabel('Number of Estimated Employed People')
# Out:
# Text(0, 0.5, 'Number of Estimated Employed People')

# %%
#Estimated Employed month Wise
data4_11_2020 = data_11_2020[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed', ascending=False)
data4_11_2020
# Out:
#        Estimated Employed
# month
# Jan             406567194
# Feb             402694917
# Sep             393871643
# Oct             393659474
# Mar             392543817
# Aug             389584135
# Jul             389286580
# Jun             374149633
# May             310699661
# Apr             274825174

# %%
#month wise Estimated Employed visualization

data4_11_2020 = data_11_2020[['month','Estimated Employed']].groupby('month').sum().sort_values('Estimated Employed', ascending=False)
data4_11_2020.head(10)
fig=plt.figure()
ax1=fig.add_subplot(1,2,2)

# employed
data4_11_2020[:10].plot(kind='bar',color='red', figsize=(15,6), ax=ax0)
ax1.set_title('Estimated Employed people in each Month')
ax1.set_title('Month')
ax1.set_ylabel('Number of Estimated Employed People')
# Out:
# Text(0, 0.5, 'Number of Estimated Employed People')

# %%
#barplot unemployment rate
fig = px.bar(data, x='State', y='Estimated Unemployment Rate', animation_frame='month', color='State', title = 'Unemployment Rate (state)')

fig.update_layout(xaxis={'categoryorder':'total descending'})

fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration']=2000

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
